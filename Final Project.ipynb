# %% [markdown]
# # Final Project - Data Science Programming
# ## Joseph Blankenship and Jacob Mitchell

# %% [markdown]
# # United States Opioid Epidemic

# %%
import pandas as pd

# %%
#Number and Age-adjusted rates of drug overdose death by state, US 2019
overdoseByState = pd.read_csv("overdoseDeathByState.csv")

#Statistically Significant drug overdose death rate increase from 2018 to 2018 US States
overdoseByState.describe()

overdoseIncrease = pd.read_csv("overdoseIncreaseRate.csv")
overdoseIncrease.describe()

medicare = pd.read_csv("medicarePrescriptionRates.csv")
medicare
# Out:
#         Year Prscrbr_Geo_Lvl  Prscrbr_Geo_Cd  \
# 0       2019        National             NaN
# 1       2019        National             NaN
# 2       2019        National             NaN
# 3       2019           State             1.0
# 4       2019           State             2.0
# ...      ...             ...             ...
# 209083  2013             ZIP         99921.0
# 209084  2013             ZIP         99922.0
# 209085  2013             ZIP         99925.0
# 209086  2013             ZIP         99926.0
# 209087  2013             ZIP         99929.0
#
#                           Prscrbr_Geo_Desc  RUCA_Cd Breakout_Type Breakout  \
# 0                                 National      NaN        Totals  Overall
# 1                                 National      NaN   Rural/Urban    Rural
# 2                                 National      NaN   Rural/Urban    Urban
# 3                                  Alabama      NaN        Totals  Overall
# 4                                   Alaska      NaN        Totals  Overall
# ...                                    ...      ...           ...      ...
# 209083  Alaska:Prince of Wales-Hyder:99921     10.0        Totals  Overall
# 209084  Alaska:Prince of Wales-Hyder:99922     10.0        Totals  Overall
# 209085  Alaska:Prince of Wales-Hyder:99925     10.0        Totals  Overall
# 209086  Alaska:Prince of Wales-Hyder:99926     10.0        Totals  Overall
# 209087               Alaska:Wrangell:99929     10.0        Totals  Overall
#
#         Tot_Prscrbrs  Tot_Opioid_Prscrbrs  Tot_Opioid_Clms      Tot_Clms  \
# 0          1239380.0             803549.0       66138200.0  1.501140e+09
# 1           134064.0              95576.0       11754049.0  2.602258e+08
# 2          1103989.0             707114.0       54351962.0  1.240046e+09
# 3            15575.0               9739.0        1814583.0  2.800821e+07
# 4             2847.0               1935.0          80311.0  1.639104e+06
# ...              ...                  ...              ...           ...
# 209083           4.0                  4.0            265.0  3.228000e+03
# 209084           2.0                  1.0              NaN  1.510000e+02
# 209085           7.0                  6.0            641.0  4.644000e+03
# 209086           1.0                  1.0             38.0  4.970000e+02
# 209087           7.0                  7.0            448.0  5.824000e+03
#
#         Opioid_Prscrbng_Rate  Opioid_Prscrbng_Rate_5Y_Chg  \
# 0                       4.41                        -1.32
# 1                       4.52                        -1.48
# 2                       4.38                        -1.29
# 3                       6.48                        -1.40
# 4                       4.90                        -2.01
# ...                      ...                          ...
# 209083                  8.21                          NaN
# 209084                   NaN                          NaN
# 209085                 13.80                          NaN
# 209086                  7.65                          NaN
# 209087                  7.69                          NaN
#
#         Opioid_Prscrbng_Rate_1Y_Chg  LA_Tot_Opioid_Clms  \
# 0                             -0.27           7290510.0
# 1                             -0.29           1211808.0
# 2                             -0.28           6735793.0
# 3                             -0.42            138456.0
# 4                             -0.90             13005.0
# ...                             ...                 ...
# 209083                          NaN                45.0
# 209084                          NaN                 NaN
# 209085                          NaN               160.0
# 209086                          NaN                 NaN
# 209087                          NaN                91.0
#
#         LA_Opioid_Prscrbng_Rate  LA_Opioid_Prscrbng_Rate_5Y_Chg  \
# 0                         11.02                           -1.73
# 1                         10.31                           -1.92
# 2                         12.39                           -1.41
# 3                          7.63                           -2.13
# 4                         16.19                           -3.73
# ...                         ...                             ...
# 209083                    16.98                             NaN
# 209084                      NaN                             NaN
# 209085                    24.96                             NaN
# 209086                      NaN                             NaN
# 209087                    20.31                             NaN
#
#         LA_Opioid_Prscrbng_Rate_1Y_Chg
# 0                                -0.77
# 1                                -0.73
# 2                                -0.68
# 3                                -0.73
# 4                                -2.42
# ...                                ...
# 209083                             NaN
# 209084                             NaN
# 209085                             NaN
# 209086                             NaN
# 209087                             NaN
#
# [209088 rows x 18 columns]
