# %% [markdown]
# # Final Project - Data Science Programming
# ## Joseph Blankenship and Jacob Mitchell

# %% [markdown]
# # United States Opioid Epidemic

# %%
import pandas as pd
import re as re

# %%
#Number and Age-adjusted rates of drug overdose death by state, US 2019
overdoseByState = pd.read_csv("overdoseDeathByState.csv")

#Statistically Significant drug overdose death rate increase from 2018 to 2018 US States
overdoseByState.describe()

overdoseIncrease = pd.read_csv("overdoseIncreaseRate.csv")
overdoseIncrease.describe()

medicare = pd.read_csv("medicarePrescriptionRates.csv")
#location = medicare["Prscrbr_Geo_Desc"]

medi_p = pd.read_csv("medicare_practice.csv")

# %%
medi_p
# Out:
#      Year Prscrbr_Geo_Lvl  Prscrbr_Geo_Cd     Prscrbr_Geo_Desc  RUCA_Cd  \
# 0    2019        National             NaN             National      NaN
# 1    2019        National             NaN             National      NaN
# 2    2019        National             NaN             National      NaN
# 3    2019           State             1.0              Alabama      NaN
# 4    2019           State             2.0               Alaska      NaN
# ..    ...             ...             ...                  ...      ...
# 350  2019          County          5139.0       Arkansas:Union      NaN
# 351  2019          County          5141.0   Arkansas:Van Buren      NaN
# 352  2019          County          5143.0  Arkansas:Washington      NaN
# 353  2019          County          5145.0       Arkansas:White      NaN
# 354  2019          County          5147.0    Arkansas:Woodruff      NaN
#
#     Breakout_Type Breakout  Tot_Prscrbrs  Tot_Opioid_Prscrbrs  \
# 0          Totals  Overall     1239380.0             803549.0
# 1     Rural/Urban    Rural      134064.0              95576.0
# 2     Rural/Urban    Urban     1103989.0             707114.0
# 3          Totals  Overall       15575.0               9739.0
# 4          Totals  Overall        2847.0               1935.0
# ..            ...      ...           ...                  ...
# 350        Totals  Overall         125.0                 93.0
# 351        Totals  Overall          30.0                 27.0
# 352        Totals  Overall         869.0                614.0
# 353        Totals  Overall         269.0                209.0
# 354        Totals  Overall           9.0                  7.0
#
#      Tot_Opioid_Clms      Tot_Clms  Opioid_Prscrbng_Rate  \
# 0         66138200.0  1.501140e+09                  4.41
# 1         11754049.0  2.602258e+08                  4.52
# 2         54351962.0  1.240046e+09                  4.38
# 3          1814583.0  2.800821e+07                  6.48
# 4            80311.0  1.639104e+06                  4.90
# ..               ...           ...                   ...
# 350          17535.0  3.221240e+05                  5.44
# 351           3285.0  9.207600e+04                  3.57
# 352          82562.0  1.094158e+06                  7.55
# 353          16938.0  5.249820e+05                  3.23
# 354            987.0  3.617400e+04                  2.73
#
#      Opioid_Prscrbng_Rate_5Y_Chg  Opioid_Prscrbng_Rate_1Y_Chg  \
# 0                          -1.32                        -0.27
# 1                          -1.48                        -0.29
# 2                          -1.29                        -0.28
# 3                          -1.40                        -0.42
# 4                          -2.01                        -0.90
# ..                           ...                          ...
# 350                        -0.47                         0.12
# 351                        -0.96                        -0.74
# 352                        -1.38                        -1.18
# 353                        -1.31                        -0.29
# 354                        -1.78                         0.00
#
#      LA_Tot_Opioid_Clms  LA_Opioid_Prscrbng_Rate  \
# 0             7290510.0                    11.02
# 1             1211808.0                    10.31
# 2             6735793.0                    12.39
# 3              138456.0                     7.63
# 4               13005.0                    16.19
# ..                  ...                      ...
# 350               981.0                     5.59
# 351               104.0                     3.17
# 352             12248.0                    14.83
# 353               788.0                     4.65
# 354                50.0                     5.07
#
#      LA_Opioid_Prscrbng_Rate_5Y_Chg  LA_Opioid_Prscrbng_Rate_1Y_Chg
# 0                             -1.73                           -0.77
# 1                             -1.92                           -0.73
# 2                             -1.41                           -0.68
# 3                             -2.13                           -0.73
# 4                             -3.73                           -2.42
# ..                              ...                             ...
# 350                           -0.50                           -1.11
# 351                           -3.42                           -1.99
# 352                           -1.88                           -3.27
# 353                           -2.26                            0.41
# 354                           -0.92                           -1.87
#
# [355 rows x 18 columns]

# %%
#type(medi_practice.Prscrbr_Geo_Desc[1])
#the locations are in strings, we can split them
med_loc = medi_p.Prscrbr_Geo_Desc
med_loc
#for Prescrbr_Geo_Desc in med_loc:
#print("x")
# Out:
# 0                 National
# 1                 National
# 2                 National
# 3                  Alabama
# 4                   Alaska
#               ...
# 350         Arkansas:Union
# 351     Arkansas:Van Buren
# 352    Arkansas:Washington
# 353         Arkansas:White
# 354      Arkansas:Woodruff
# Name: Prscrbr_Geo_Desc, Length: 355, dtype: object

# %%
#This cycles through the series and finds a char in the string in the series row
for Prescrbr_Geo_Desc in med_loc:
    #num = 0
    found_num = Prescrbr_Geo_Desc.find(":") #returns -1 for not found, otherwise pos of char
    if(found_num > 0):
        print(Prescrbr_Geo_Desc)
# Out:
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# Alabama:Autauga
# Alabama:Baldwin
# Alabama:Barbour
# Alabama:Bibb
# Alabama:Blount
# Alabama:Bullock
# Alabama:Butler
# Alabama:Calhoun
# Alabama:Chambers
# Alabama:Cherokee
# Alabama:Chilton
# Alabama:Choctaw
# Alabama:Clarke
# Alabama:Clay
# Alabama:Cleburne
# Alabama:Coffee
# Alabama:Colbert
# Alabama:Conecuh
# Alabama:Coosa
# Alabama:Covington
# Alabama:Crenshaw
# Alabama:Cullman
# Alabama:Dale
# Alabama:Dallas
# Alabama:DeKalb
# Alabama:Elmore
# Alabama:Escambia
# Alabama:Etowah
# Alabama:Fayette
# Alabama:Franklin
# Alabama:Geneva
# Alabama:Greene
# Alabama:Hale
# Alabama:Henry
# Alabama:Houston
# Alabama:Jackson
# Alabama:Jefferson
# Alabama:Lamar
# Alabama:Lauderdale
# Alabama:Lawrence
# Alabama:Lee
# Alabama:Limestone
# Alabama:Lowndes
# Alabama:Macon
# Alabama:Madison
# Alabama:Marengo
# Alabama:Marion
# Alabama:Marshall
# Alabama:Mobile
# Alabama:Monroe
# Alabama:Montgomery
# Alabama:Morgan
# Alabama:Perry
# Alabama:Pickens
# Alabama:Pike
# Alabama:Randolph
# Alabama:Russell
# Alabama:St. Clair
# Alabama:Shelby
# Alabama:Sumter
# Alabama:Talladega
# Alabama:Tallapoosa
# Alabama:Tuscaloosa
# Alabama:Walker
# Alabama:Washington
# Alabama:Wilcox
# Alabama:Winston
# Alaska:Aleutians East
# Alaska:Aleutians West
# Alaska:Anchorage
# Alaska:Bethel
# Alaska:Bristol Bay
# Alaska:Denali
# Alaska:Dillingham
# Alaska:Fairbanks North Star
# Alaska:Haines
# Alaska:Hoonah-Angoon
# Alaska:Juneau
# Alaska:Kenai Peninsula
# Alaska:Ketchikan Gateway
# Alaska:Kodiak Island
# Alaska:Kusilvak
# Alaska:Lake and Peninsula
# Alaska:Matanuska-Susitna
# Alaska:Nome
# Alaska:North Slope
# Alaska:Northwest Arctic
# Alaska:Petersburg
# Alaska:Prince of Wales-Hyder
# Alaska:Sitka
# Alaska:Skagway
# Alaska:Southeast Fairbanks
# Alaska:Wrangell
# Alaska:Yakutat
# Alaska:Yukon-Koyukuk
# Arizona:Apache
# Arizona:Cochise
# Arizona:Coconino
# Arizona:Gila
# Arizona:Graham
# Arizona:Greenlee
# Arizona:La Paz
# Arizona:Maricopa
# Arizona:Mohave
# Arizona:Navajo
# Arizona:Pima
# Arizona:Pinal
# Arizona:Santa Cruz
# Arizona:Yavapai
# Arizona:Yuma
# Arkansas:Arkansas
# Arkansas:Ashley
# Arkansas:Baxter
# Arkansas:Benton
# Arkansas:Boone
# Arkansas:Bradley
# Arkansas:Calhoun
# Arkansas:Carroll
# Arkansas:Chicot
# Arkansas:Clark
# Arkansas:Clay
# Arkansas:Cleburne
# Arkansas:Cleveland
# Arkansas:Columbia
# Arkansas:Conway
# Arkansas:Craighead
# Arkansas:Crawford
# Arkansas:Crittenden
# Arkansas:Cross
# Arkansas:Dallas
# Arkansas:Desha
# Arkansas:Drew
# Arkansas:Faulkner
# Arkansas:Franklin
# Arkansas:Fulton
# Arkansas:Garland
# Arkansas:Grant
# Arkansas:Greene
# Arkansas:Hempstead
# Arkansas:Hot Spring
# Arkansas:Howard
# Arkansas:Independence
# Arkansas:Izard
# Arkansas:Jackson
# Arkansas:Jefferson
# Arkansas:Johnson
# Arkansas:Lafayette
# Arkansas:Lawrence
# Arkansas:Lee
# Arkansas:Lincoln
# Arkansas:Little River
# Arkansas:Logan
# Arkansas:Lonoke
# Arkansas:Madison
# Arkansas:Marion
# Arkansas:Miller
# Arkansas:Mississippi
# Arkansas:Monroe
# Arkansas:Montgomery
# Arkansas:Nevada
# Arkansas:Newton
# Arkansas:Ouachita
# Arkansas:Perry
# Arkansas:Phillips
# Arkansas:Pike
# Arkansas:Poinsett
# Arkansas:Polk
# Arkansas:Pope
# Arkansas:Prairie
# Arkansas:Pulaski
# Arkansas:Randolph
# Arkansas:St. Francis
# Arkansas:Saline
# Arkansas:Scott
# Arkansas:Searcy
# Arkansas:Sebastian
# Arkansas:Sevier
# Arkansas:Sharp
# Arkansas:Stone
# Arkansas:Union
# Arkansas:Van Buren
# Arkansas:Washington
# Arkansas:White
# Arkansas:Woodruff
